# %% [markdown]
# ## 模型评价指标

# %% [markdown]
# ### 分类

# %% [markdown]
# ### 回归

# %% [markdown]
# #### 1、MSE
# - 真实值-预测值 然后平方之后求和平均![image.png](attachment:image.png)

# %% [markdown]
# #### 2、RMSE
# - MSE开方，可以解决量纲问题
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3、R^2
# -

# %%
# sklearn 实现
from sklearn.metrics import mean_squared_error #均方误差
from sklearn.metrics import r2_score#R square
#调用
MSE = mean_squared_error(y_test,y_predict)
RMSE = np.sqrt(MSE)
R2 = r2_score(y_test,y_predict)

# %% [markdown]
# ### 交叉验证

# %% [markdown]
# ### 过拟合与欠拟合

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 过拟合、欠拟合与偏差、方差的关系
# - 过拟合 - 模型复杂 - 方差较大
# - 欠拟合 - 模型简单 - 偏差较大

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 正则化
# - 正则化框架
#     - argmin(L(w)+λP(w))
